# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5,5)

# %%
x
# Out:
# array([-5, -4, -3, -2, -1,  0,  1,  2,  3,  4])

# %%
BMAX = 20000
def bellcurve(x):
    mu = 0
    sig = 0.05*BMAX #knee curve starts at 25% of BMAX
    if(np.abs(x) <= 0.12*BMAX):
        norm_reward = (np.exp(-np.power((x - mu)/sig, 2.)/2) / np.exp(-np.power((0 - mu)/sig, 2.)/2))
    else:
        norm_reward = -0.25 -2.5*np.abs(x/BMAX)
    
    return norm_reward*400

def drewardfn(x):
        mu = 0
        sig = 1000
        if(np.abs(x) <= 2400): #24hr * 100mW/hr
            return ((1./(np.sqrt(2.*np.pi)*sig)*np.exp(-np.power((x - mu)/sig, 2.)/2)) * 1000000)
        else:
            return -100 - 0.05*np.abs(x)

# %%
y1 = np.empty(1)
y2 = np.empty(1)

for x in np.arange(-BMAX/4,BMAX/4):
    y1 = np.append(y1,bellcurve(x))
    y2 = np.append(y2,drewardfn(x))
y1 = np.delete(y1, 0, 0) #remove the first row which is garbage
y2 = np.delete(y2, 0, 0) #remove the first row which is garbage


enp = np.arange(-BMAX/4,BMAX/4)
fig, ax = plt.subplots()
ax.plot(enp, y1)
ax.plot(enp, y2, 'r--')

ax.set(xlabel='ENP', ylabel='Reward',
       title='Reward Function')
ax.grid()
plt.show()

# %%
BMAX = 20000
y1 = np.empty(1)
for x in np.arange(-BMAX/2,BMAX/2):
    y1 = np.append(y1,drewardfn(x))
y1 = np.delete(y1, 0, 0) #remove the first row which is garbage

enp = np.arange(-BMAX/2,BMAX/2)
fig, ax = plt.subplots()
ax.plot(enp, y1)

ax.set(xlabel='ENP', ylabel='Reward',
       title='Reward Function')
ax.grid()
plt.show()

# %%
55e-3
# Out:
# 0.055

# %%
4e-2
# Out:
# 0.04

# %%
from eno_class import *
test = ENO('tokyo',2010,shuffle=False) #refer to eno_class.py class file
test.reset()
# Out:
# [0.0, 0, False, False]

# %%
csenergy = test.senergy
day_energy = np.sum(csenergy, axis=1)

# %%
import matplotlib.pyplot as plt
plt.plot(day_energy)
plt.grid()
plt.show()

# %%
np.amax(day_energy)
# Out:
# 4611.979166666668

# %%
np.amin(day_energy)
# Out:
# 120.31250000000001

# %%
np.mean(day_energy)
# Out:
# 2129.3444634703196

# %%
plt.hist(day_energy, bins = 6, rwidth=0.75)
# Out:
# (array([ 58.,  65., 103.,  56.,  45.,  38.]),
#  array([ 120.3125    ,  868.92361111, 1617.53472222, 2366.14583333,
#         3114.75694444, 3863.36805556, 4611.97916667]),
#  <a list of 6 Patch objects>)

# %%
0.0165*1000000*0.15*1000/(60*60)
# Out:
# 687.5

# %%
1e6 * (55e-3 * 70e-3) * 0.15 * 1000/(60*60)
# Out:
# 160.41666666666666

# %%
687.5/160.4
# Out:
# 4.2861596009975065

# %%
12000/(0.0165*1000000*0.15*1000/(60*60) )
# Out:
# 17.454545454545453

# %%
3.7*np.array([500,2000,2500,1200,6600])
# Out:
# array([ 1850.,  7400.,  9250.,  4440., 24420.])

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = [0,5,9,10,15]
y = [0,1,2,3,4]
plt.plot(x,y)
plt.xticks(np.arange(min(x), max(x)+1, 3.0))
plt.show()

# %%
[ 10,  11,  31,  40,  41,  42,  43,  45,  46,  64,  65,  67,  82,
        83,  91,  94,  96, 101, 104, 111, 112, 130, 143, 250, 258, 265,
       269, 270, 272, 281, 293, 300, 302, 320, 346, 347, 349]

# %%
for i in range(20,29):
    print(i)
# Out:
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 27
# 28

# %%
x
# Out:
# range(20, 29)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
VTh = 0.1
x = np.arange(0.1,0.35,0.001)
# y = x * 2
y = 1*np.exp((x)/VTh)/np.exp(0.35/VTh)
plt.plot(x,y)

# %%
np.exp((0.2)/VTh)/np.exp(0.7/VTh)
# Out:
# 0.08208499862389883

# %%
btrack = []

# %%
btrack = np.append(btrack, 1)
btrack = np.append(btrack, 2)
btrack = np.append(btrack, 3)
btrack = np.append(btrack, 4)

# %%
btrack
# Out:
# array([1., 2., 3., 4.])

# %%
np.mean(btrack)
# Out:
# 2.5

# %%
btrack = []

# %%
btrack = np.append(btrack, 5)
btrack = np.append(btrack, 6)
btrack = np.append(btrack, 7)
btrack = np.append(btrack, 8)

# %%
btrack
# Out:
# array([5., 6., 7., 8.])

# %%
import numpy as np
import matplotlib.pyplot as plt

BMAX = 9250

def drewardfn(enp):
    if(np.abs(enp/BMAX) <= 0.1):
        norm_reward = 1
    else:
        norm_reward =  -5*np.abs(enp/BMAX) +0.5
    return norm_reward

# %%
y1 = []
enp = np.arange(-BMAX/2,BMAX/2)
for x in np.arange(-BMAX/2,BMAX/2):
    y1 = np.append(y1,drewardfn(x))
plt.plot(enp/BMAX,y1)

# %%
import numpy as np
import matplotlib.pyplot as plt

BMAX = 9250

def brewardfn(bdev):
    if (bdev <= 0.1):
        penalty = 0
    else:
        VTh = 0.1
        penalty = np.exp((bdev)/VTh)/np.exp(0.3/VTh)- np.exp(0.1/VTh)/np.exp(0.3/VTh)
                                                      
    return 1- penalty

# %%
y1 = []
bdev = np.arange(0,0.3,0.001)
for x in np.arange(0,0.3,0.001):
    y1 = np.append(y1,brewardfn(x))
plt.plot(bdev,y1)

# %%
brewardfn(0.35)
# Out:
# 1.5133859874635154

# %%
y =5
y /= 2

# %%
y
# Out:
# 2.5

# %%
import random
random.choice(['tokyo','wakkanai','minamidaito'])
# Out:
# 'minamidaito'

# %%
import random
import numpy as np


random.choice(np.arange(2010,2015))
# Out:
# 2013

# %%
import random
import numpy as np

a = np.random.rand(3,2)
print(a)
x = np.random.choice(a[1])
print(x)
# Out:
# [[0.30142836 0.50444839]
#  [0.01837199 0.73910099]
#  [0.57019517 0.73779434]]
# 0.7391009914472251
